# %%
# Write your imports here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from collections import Counter
from nltk.tokenize import word_tokenize, sent_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ferad\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ferad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ferad\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# # Working with Text Lab
# ## Information retrieval, preprocessing, and feature extraction

# %% [markdown]
# In this lab, you'll be looking at and exploring European restaurant reviews. The dataset is rather tiny, but that's just because it has to run on any machine. In real life, just like with images, texts can be several terabytes long.
#
# The dataset is located [here](https://www.kaggle.com/datasets/gorororororo23/european-restaurant-reviews) and as always, it's been provided to you in the `data/` folder.

# %% [markdown]
# ### Problem 1. Read the dataset (1 point)
# Read the dataset, get acquainted with it. Ensure the data is valid before you proceed.
#
# How many observations are there? Which country is the most represented? What time range does the dataset represent?
#
# Is the sample balanced in terms of restaurants, i.e., do you have an equal number of reviews for each one? Most importantly, is the dataset balanced in terms of **sentiment**?

# %%
restaurant_reviews = pd.read_csv("data/European Restaurant Reviews.csv")
restaurant_reviews
# Out:
#      Country            Restaurant Name Sentiment  \
# 0     France  The Frog at Bercy Village  Negative
# 1     France  The Frog at Bercy Village  Negative
# 2     France  The Frog at Bercy Village  Negative
# 3     France  The Frog at Bercy Village  Negative
# 4     France  The Frog at Bercy Village  Negative
# ...      ...                        ...       ...
# 1497    Cuba   Old Square (Plaza Vieja)  Negative
# 1498    Cuba   Old Square (Plaza Vieja)  Negative
# 1499    Cuba   Old Square (Plaza Vieja)  Negative
# 1500    Cuba   Old Square (Plaza Vieja)  Negative
# 1501    Cuba   Old Square (Plaza Vieja)  Negative
#
#                                    Review Title Review Date  \
# 0                                  Rude manager  May 2024 •
# 1                          A big disappointment  Feb 2024 •
# 2                  Pretty Place with Bland Food  Nov 2023 •
# 3      Great service and wine but inedible food  Mar 2023 •
# 4     Avoid- Worst meal in Rome - possibly ever  Nov 2022 •
# ...                                         ...         ...
# 1497                           The Tourism Trap  Oct 2016 •
# 1498                           the beer factory  Oct 2016 •
# 1499                                    brewery  Oct 2016 •
# 1500           It's nothing exciting over there  Oct 2016 •
# 1501                               Tourist Trap  Oct 2016 •
#
#                                                  Review
# 0     The manager became agressive when I said the c...
# 1     I ordered a beef fillet ask to be done medium,...
# 2     This is an attractive venue with welcoming, al...
# 3     Sadly I  used the high TripAdvisor rating too ...
# 4     From the start this meal was bad- especially g...
# ...                                                 ...
# 1497  Despite the other reviews saying that this is ...
# 1498  beer is good.  food is awfull  The only decent...
# 1499  for terrible service of a truly comedic level,...
# 1500  We visited the Havana's Club Museum which is l...
# 1501  Food and service was awful. Very pretty stop. ...
#
# [1502 rows x 6 columns]

# %%
restaurant_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          1502 non-null   object
#  1   Restaurant Name  1502 non-null   object
#  2   Sentiment        1502 non-null   object
#  3   Review Title     1502 non-null   object
#  4   Review Date      1502 non-null   object
#  5   Review           1502 non-null   object
# dtypes: object(6)
# memory usage: 70.5+ KB

# %%
restaurant_reviews.Country.value_counts()
# Out:
# Country
# France     512
# Italy      318
# Morroco    210
# Cuba       146
# Poland     135
# Russia     100
# India       81
# Name: count, dtype: int64

# %% [markdown]
# There are a total of 1502 observations and the most represented country is France. Lets first change the column names to snake case.

# %%
column_names = [col.replace(" ", "_").lower() for col in restaurant_reviews.columns]
restaurant_reviews.columns = column_names
restaurant_reviews.columns
# Out:
# Index(['country', 'restaurant_name', 'sentiment', 'review_title',
#        'review_date', 'review'],
#       dtype='object')

# %% [markdown]
#  To see the dates range, I will need to first convert the Review Date column to **datetime** type. There also seems to be a dot after the date, which also has to be removed

# %%
restaurant_reviews.review_date = restaurant_reviews.review_date.str.replace(" •", "")

# %%
restaurant_reviews.review_date =  pd.to_datetime(restaurant_reviews.review_date, format = "mixed")
restaurant_reviews.review_date
# Out:
# 0      2024-05-01
# 1      2024-02-01
# 2      2023-11-01
# 3      2023-03-01
# 4      2022-11-01
#           ...
# 1497   2016-10-01
# 1498   2016-10-01
# 1499   2016-10-01
# 1500   2016-10-01
# 1501   2016-10-01
# Name: review_date, Length: 1502, dtype: datetime64[ns]

# %%
print("Start date: " + str(restaurant_reviews.review_date.max()))
print("End date: " + str(restaurant_reviews.review_date.min()))

period = restaurant_reviews.review_date.max() - restaurant_reviews.review_date.min()
years = period.days // 365
months = (period.days % 365) // 30
days = (period.days % 365) % 30
print(f"Total period is {years} years, {months} months and {days} days")
# Out:
# Start date: 2024-07-01 00:00:00
# End date: 2010-09-01 00:00:00
# Total period is 13 years, 10 months and 7 days

# %%
restaurant_reviews.restaurant_name.value_counts()
# Out:
# restaurant_name
# The Frog at Bercy Village                512
# Ad Hoc Ristorante (Piazza del Popolo)    318
# The LOFT                                 210
# Old Square (Plaza Vieja)                 146
# Stara Kamienica                          135
# Pelmenya                                 100
# Mosaic                                    81
# Name: count, dtype: int64

# %% [markdown]
# The sample is not balanced in terms of restaurants. There is a big differnce in the number of reviews for each one.

# %%
restaurant_reviews.sentiment.value_counts()
# Out:
# sentiment
# Positive    1237
# Negative     265
# Name: count, dtype: int64

# %% [markdown]
# It's also not balanced in terms of reviews. The positive reviews are a lot more than the negative ones.

# %% [markdown]
# ### Problem 2. Getting acquainted with reviews (1 point)
# Are positive comments typically shorter or longer? Try to define a good, robust metric for "length" of a text; it's not necessary just the character count. Can you explain your findings?

# %% [markdown]
# To see the length of each review, lets try to get the word count of each one, but remove the punctuation symbols. The result will be saved in a new column.

# %%
def count_words(sentence):
    tokens = word_tokenize(sentence) #Create a list of all separate words or characters
    filtered_words = [word for word in tokens if word.isalnum()] #Filters out the punctuation symbols
    return len(filtered_words) #Get the length of the filtered words list

restaurant_reviews["review_length"] = restaurant_reviews.review.apply(count_words)

# %%
restaurant_reviews.review_length
# Out:
# 0        28
# 1        57
# 2        40
# 3       276
# 4       246
#        ...
# 1497    144
# 1498     30
# 1499     27
# 1500     69
# 1501     14
# Name: review_length, Length: 1502, dtype: int64

# %% [markdown]
# Now lets check which review type is typically longer - Positive or Negative. To do that I will get the average length of reviews of both types.

# %%
average_word_count = restaurant_reviews.groupby('sentiment')['review_length'].mean()
average_word_count
# Out:
# sentiment
# Negative    139.358491
# Positive     49.666128
# Name: review_length, dtype: float64

# %% [markdown]
# It looks like the negative reviews on average are *waaay* longer than the positive ones. I think that makes sense, considering that people like to talk more and longer about something when they are unhappy about it, than when they are happy.

# %% [markdown]
# ### Problem 3. Preprocess the review content (2 points)
# You'll likely need to do this while working on the problems below, but try to synthesize (and document!) your preprocessing here. Your tasks will revolve around words and their connection to sentiment. While preprocessing, keep in mind the domain (restaurant reviews) and the task (sentiment analysis).

# %% [markdown]
# To process the review content, I will remove the punctuation symbols and the words that carry no information. To do so I will clear the sentences of **stopwords** *(from stopwords in nltk.corpus)*

# %%
stop_words = set(stopwords.words('english'))
for word in stop_words:
    print(word, end = " ")
# Out:
# did hadn weren so about below its over until into have how hadn't mustn't out you'll off such those m yourselves should've through itself can i his didn isn't my now of there ours when myself nor at same we it don't above that re mightn why again or for me most hasn't yours what they y ll each just couldn't doing been haven mightn't wouldn't she you've don is where needn't who himself shouldn him was being hers shan't t them you're herself further shan our ain more by and any isn not the ve on mustn does d having both couldn should because to it's while had yourself she's her no than will after ourselves won didn't o whom be am doesn own shouldn't has needn once ma wasn were this too but s during very before few if against in their hasn won't here these he other doesn't haven't weren't you'd up all some aren only an do wasn't which between as aren't that'll your with theirs then are you down themselves from a wouldn under

# %%
def remove_stop_words_and_punctuation(sentence):
    tokens = word_tokenize(sentence)
    filtered_words = [word.lower() for word in tokens if word.lower() not in stop_words and word.isalnum()]
    return ' '.join(filtered_words)

restaurant_reviews["clean_reviews"] = restaurant_reviews.review.apply(remove_stop_words_and_punctuation)

# %%
restaurant_reviews["clean_reviews"]
# Out:
# 0       manager became agressive said carbonara good r...
# 1       ordered beef fillet ask done medium got well d...
# 2       attractive venue welcoming albeit somewhat slo...
# 3       sadly used high tripadvisor rating literally f...
# 4       start meal especially given price visited husb...
#                               ...
# 1497    despite reviews saying place hang especially b...
# 1498    beer good food awfull decent thing shish kabob...
# 1499    terrible service truly comedic level full pint...
# 1500    visited havana club museum located old havana ...
# 1501    food service awful pretty stop good photos bad...
# Name: clean_reviews, Length: 1502, dtype: object

# %% [markdown]
# ### Problem 3. Top words (1 point)
# Use a simple word tokenization and count the top 10 words in positive reviews; then the top 10 words in negative reviews*. Once again, try to define what "top" words means. Describe and document your process. Explain your results.
#
# \* Okay, you may want to see top N words (with $N \ge 10$).

# %% [markdown]
# I will first create lists of all words used in the positive reviews and all words used in the negative reviews. Then count the top values in both of them using **Counter** from **collections** library.

# %%
positive_reviews_words = []
for review in restaurant_reviews[restaurant_reviews.sentiment == "Positive"]['clean_reviews']:
    positive_reviews_words.extend(word_tokenize(review))
    
negative_reviews_words = []
for review in restaurant_reviews[restaurant_reviews.sentiment == "Negative"]['clean_reviews']:
    negative_reviews_words.extend(review.split(" "))

# %%
positive_words_counter = Counter(positive_reviews_words)
positive_words_counter.most_common(10)
# Out:
# [('food', 739),
#  ('great', 571),
#  ('service', 538),
#  ('good', 512),
#  ('place', 373),
#  ('restaurant', 352),
#  ('nice', 307),
#  ('staff', 258),
#  ('wine', 239),
#  ('menu', 235)]

# %%
negative_words_counter = Counter(negative_reviews_words)
negative_words_counter.most_common(100)
# Out:
# [('food', 247),
#  ('us', 205),
#  ('restaurant', 185),
#  ('wine', 175),
#  ('good', 153),
#  ('table', 147),
#  ('service', 146),
#  ('one', 134),
#  ('menu', 131),
#  ('would', 130),
#  ('rome', 107),
#  ('could', 101),
#  ('place', 98),
#  ('meal', 95),
#  ('nice', 87),
#  ('waitress', 86),
#  ('really', 86),
#  ('like', 86),
#  ('time', 85),
#  ('ad', 84),
#  ('asked', 83),
#  ('hoc', 82),
#  ('even', 73),
#  ('minutes', 72),
#  ('tasting', 72),
#  ('took', 71),
#  ('truffle', 68),
#  ('many', 67),
#  ('restaurants', 66),
#  ('go', 66),
#  ('course', 65),
#  ('made', 63),
#  ('main', 63),
#  ('night', 62),
#  ('served', 62),
#  ('evening', 62),
#  ('reviews', 62),
#  ('well', 60),
#  ('never', 60),
#  ('reservation', 60),
#  ('glass', 60),
#  ('next', 59),
#  ('average', 58),
#  ('left', 54),
#  ('said', 53),
#  ('way', 53),
#  ('experience', 52),
#  ('great', 52),
#  ('bill', 52),
#  ('told', 51),
#  ('pasta', 51),
#  ('cold', 51),
#  ('back', 50),
#  ('also', 50),
#  ('price', 48),
#  ('without', 48),
#  ('came', 48),
#  ('ordered', 46),
#  ('arrived', 46),
#  ('get', 46),
#  ('got', 45),
#  ('better', 45),
#  ('much', 44),
#  ('people', 44),
#  ('best', 43),
#  ('nothing', 43),
#  ('decided', 43),
#  ('2', 43),
#  ('hours', 43),
#  ('hour', 43),
#  ('dinner', 43),
#  ('staff', 42),
#  ('two', 42),
#  ('order', 42),
#  ('ask', 41),
#  ('another', 41),
#  ('eat', 41),
#  ('bad', 40),
#  ('3', 40),
#  ('think', 40),
#  ('first', 39),
#  ('long', 38),
#  ('truffles', 37),
#  ('looking', 37),
#  ('terrible', 36),
#  ('last', 36),
#  ('slow', 35),
#  ('disappointed', 35),
#  ('prosecco', 35),
#  ('courses', 35),
#  ('square', 35),
#  ('taste', 34),
#  ('dishes', 34),
#  ('ok', 34),
#  ('anything', 34),
#  ('dish', 33),
#  ('plate', 33),
#  ('went', 33),
#  ('money', 32),
#  ('seated', 32)]

# %% [markdown]
# The top words for both review types are pretty much the same and as expected are words like food, wine, service, restaurant etc. However the negative reviews are not what I expected to get. In order to actually get to the *negative* words, I need to showcase the first **100** just to get words like *disappointed', 'terrible','slow'*. There are a lot of seemingly positive words in the top words for the negative reviews, such as *'good', 'nice', 'like'*, but the words are most likely in combinations like *'not good'*, *'not nice'* etc:

# %%
restaurant_reviews[(restaurant_reviews['clean_reviews'].str.contains("good", case=False)) & (restaurant_reviews['sentiment'] == "Negative")]
# Out:
#      country            restaurant_name sentiment  \
# 0     France  The Frog at Bercy Village  Negative
# 3     France  The Frog at Bercy Village  Negative
# 4     France  The Frog at Bercy Village  Negative
# 5     France  The Frog at Bercy Village  Negative
# 8     France  The Frog at Bercy Village  Negative
# ...      ...                        ...       ...
# 1485    Cuba   Old Square (Plaza Vieja)  Negative
# 1489    Cuba   Old Square (Plaza Vieja)  Negative
# 1493    Cuba   Old Square (Plaza Vieja)  Negative
# 1498    Cuba   Old Square (Plaza Vieja)  Negative
# 1501    Cuba   Old Square (Plaza Vieja)  Negative
#
#                                            review_title review_date  \
# 0                                          Rude manager  2024-05-01
# 3              Great service and wine but inedible food  2023-03-01
# 4             Avoid- Worst meal in Rome - possibly ever  2022-11-01
# 5     Shocking management, TERRIBLE service by mum a...  2021-07-01
# 8                   Expensive mediocre food and service  2019-06-01
# ...                                                 ...         ...
# 1485                Not much there but expensivwe shops  2016-10-01
# 1489                                   the beer factory  2016-10-01
# 1493                                       Tourist Trap  2016-10-01
# 1498                                   the beer factory  2016-10-01
# 1501                                       Tourist Trap  2016-10-01
#
#                                                  review  review_length  \
# 0     The manager became agressive when I said the c...             28
# 3     Sadly I  used the high TripAdvisor rating too ...            276
# 4     From the start this meal was bad- especially g...            246
# 5     We visited this restaurant on Saturday night a...            336
# 8     We got the Tasting Menu and wine pairing. Fran...             43
# ...                                                 ...            ...
# 1485  We went there but did not stay long as there w...             64
# 1489  beer is good.  food is awfull  The only decent...             30
# 1493  Food and service was awful. Very pretty stop. ...             14
# 1498  beer is good.  food is awfull  The only decent...             30
# 1501  Food and service was awful. Very pretty stop. ...             14
#
#                                           clean_reviews
# 0     manager became agressive said carbonara good r...
# 3     sadly used high tripadvisor rating literally f...
# 4     start meal especially given price visited husb...
# 5     visited restaurant saturday night disappointin...
# 8     got tasting menu wine pairing frankly food tas...
# ...                                                 ...
# 1485  went stay long really nothing expensive clothi...
# 1489  beer good food awfull decent thing shish kabob...
# 1493  food service awful pretty stop good photos bad...
# 1498  beer good food awfull decent thing shish kabob...
# 1501  food service awful pretty stop good photos bad...
#
# [104 rows x 8 columns]

# %% [markdown]
# ### Problem 4. Review titles (2 point)
# How do the top words you found in the last problem correlate to the review titles? Do the top 10 words (for each sentiment) appear in the titles at all? Do reviews which contain one or more of the top words have the same words in their titles?
#
# Does the title of a comment present a good summary of its content? That is, are the titles descriptive, or are they simply meant to catch the attention of the reader?

# %%
#Get sets of the top 10 words
top_10_positive = set(positive_words_counter.most_common(10)[0])
top_10_negative = set(negative_words_counter.most_common(10)[0])

# %%
#Create a function to get a set of words
def get_words(text):
    tokens = word_tokenize(text.lower())
    return set(word for word in tokens if word.isalnum())

#Create an additional column, containing a set of the title words
restaurant_reviews['title_words'] = restaurant_reviews.review_title.apply(get_words)

# %%
restaurant_reviews.title_words
# Out:
# 0                                        {manager, rude}
# 1                               {disappointment, big, a}
# 2                     {food, bland, pretty, place, with}
# 3       {and, great, inedible, food, but, wine, service}
# 4                {in, ever, meal, rome, worst, possibly}
#                               ...
# 1497                                {trap, the, tourism}
# 1498                                {beer, the, factory}
# 1499                                           {brewery}
# 1500                {exciting, it, there, over, nothing}
# 1501                                     {trap, tourist}
# Name: title_words, Length: 1502, dtype: object

# %%
#Get lists containing common words between title and review for positive and negative reviews
positive_common_words = (restaurant_reviews[restaurant_reviews.sentiment == "Positive"]
                         .apply(lambda row: len(row.title_words & top_10_positive), axis = 1))
negative_common_words = (restaurant_reviews[restaurant_reviews.sentiment == "Negative"]
                         .apply(lambda row: len(row.title_words & top_10_negative), axis = 1))

# %%
#Get only the values that are not 0
positive_common_words = positive_common_words[positive_common_words > 0]
negative_common_words = negative_common_words[negative_common_words > 0]
print(f"Number of titles, containing at least one of the top 10 words for:\nnegative reviews: {len(negative_common_words)}\npositive reviews: {len(positive_common_words)}")
# Out:
# Number of titles, containing at least one of the top 10 words for:
# negative reviews: 32
# positive reviews: 178

# %%
restaurant_reviews.sentiment.value_counts()
# Out:
# sentiment
# Positive    1237
# Negative     265
# Name: count, dtype: int64

# %% [markdown]
# We can see that only a small percentage of titles contain one of the top words.

# %%
restaurant_reviews.loc[negative_common_words.index]
# Out:
#      country                        restaurant_name sentiment  \
# 2     France              The Frog at Bercy Village  Negative
# 3     France              The Frog at Bercy Village  Negative
# 8     France              The Frog at Bercy Village  Negative
# 14    France              The Frog at Bercy Village  Negative
# 22    France              The Frog at Bercy Village  Negative
# 46    France              The Frog at Bercy Village  Negative
# 51    France              The Frog at Bercy Village  Negative
# 55    France              The Frog at Bercy Village  Negative
# 59    France              The Frog at Bercy Village  Negative
# 60    France              The Frog at Bercy Village  Negative
# 61    France              The Frog at Bercy Village  Negative
# 81    France              The Frog at Bercy Village  Negative
# 86    France              The Frog at Bercy Village  Negative
# 90    France              The Frog at Bercy Village  Negative
# 95    France              The Frog at Bercy Village  Negative
# 98    France              The Frog at Bercy Village  Negative
# 104   France              The Frog at Bercy Village  Negative
# 109   France              The Frog at Bercy Village  Negative
# 122   France              The Frog at Bercy Village  Negative
# 129   France              The Frog at Bercy Village  Negative
# 134   France              The Frog at Bercy Village  Negative
# 147   France              The Frog at Bercy Village  Negative
# 514    Italy  Ad Hoc Ristorante (Piazza del Popolo)  Negative
# 521    Italy  Ad Hoc Ristorante (Piazza del Popolo)  Negative
# 526    Italy  Ad Hoc Ristorante (Piazza del Popolo)  Negative
# 539    Italy  Ad Hoc Ristorante (Piazza del Popolo)  Negative
# 544    Italy  Ad Hoc Ristorante (Piazza del Popolo)  Negative
# 549    Italy  Ad Hoc Ristorante (Piazza del Popolo)  Negative
# 831   Poland                        Stara Kamienica  Negative
# 839   Poland                        Stara Kamienica  Negative
# 841   Poland                        Stara Kamienica  Negative
# 1053  Russia                               Pelmenya  Negative
#
#                                            review_title review_date  \
# 2                          Pretty Place with Bland Food  2023-11-01
# 3              Great service and wine but inedible food  2023-03-01
# 8                   Expensive mediocre food and service  2019-06-01
# 14                         Great wines but average food  2018-07-01
# 22      Regrettable food-- cold pasta carbonara in Rome  2017-06-01
# 46              POOR SERVICE. Great atmosphere. Ok food  2015-08-01
# 51              Great ambience but the food quality ???  2015-04-01
# 55                           Great staff, terrible food  2022-02-01
# 59                           Overpriced for subpar food  2022-02-01
# 60                        Bad service and mediocre food  2022-02-01
# 61              Food in perfection but lack of service!  2022-02-01
# 81                               Nice people, okay food  2022-02-01
# 86            Average food, terrible service - OVERATED  2013-01-01
# 90             Food was average, Service was a Let Down  2022-02-01
# 95                 A big disappointment to food lover!!  2022-02-01
# 98    MAJOR Disappointment...Terrible Service....Ave...  2012-05-01
# 104   Very bad food and service - not worthy the mon...  2011-11-01
# 109   Very slow, average food, lack of wine, totally...  2011-12-01
# 122   Lots of fancy talk about their food and wines....  2022-02-01
# 129                Bad tasting food difficult to digest  2023-10-01
# 134   Very slow, average food, lack of wine, totally...  2011-12-01
# 147   Lots of fancy talk about their food and wines....  2022-02-01
# 514   Lots of fancy talk about their food and wines....  2022-02-01
# 521                Bad tasting food difficult to digest  2023-10-01
# 526   Very slow, average food, lack of wine, totally...  2011-12-01
# 539   Lots of fancy talk about their food and wines....  2022-02-01
# 544                Bad tasting food difficult to digest  2023-10-01
# 549   Very slow, average food, lack of wine, totally...  2011-12-01
# 831                            Unbelievable boring food  2024-04-01
# 839                          Good food but ripped off!!  2016-10-01
# 841                         Good food, poor management.  2015-12-01
# 1053                         Cheap food, cheaper taste.  2017-01-01
#
#                                                  review  review_length  \
# 2     This is an attractive venue with welcoming, al...             40
# 3     Sadly I  used the high TripAdvisor rating too ...            276
# 8     We got the Tasting Menu and wine pairing. Fran...             43
# 14    We both ate the truffle tasting menu with wine...             53
# 22    I don't write negative reviews. I'd rather say...            396
# 46    Can't understand it is number two of the price...            112
# 51    Ad Hoc restaurant had a top 60 rating in Rome ...            235
# 55    The only reason I'm giving it a poor and not t...            223
# 59    I saw the amazing reviews on TA so decided to ...             74
# 60    Bad service, literally had to flag down the wa...             89
# 61    Ristorante AdHoc in Rome brings out the best f...             57
# 81    Not sure why this restaurant is so well review...             60
# 86    We were more than excited to be visiting the "...             59
# 90    Service staff couldn't even be bothered to tel...            124
# 95    Go Ad Hoc if you don't mind articifical servic...            223
# 98    I give the food 3 stars (average) and service ...            563
# 104   You arrived 10 min earlier, and had to wait in...            102
# 109   Visited Ad Hoc for NYE with my husband and was...            435
# 122   Agree with all previous negative reviews.Arriv...             64
# 129   We didn't like the food that much.\n\nThe star...             61
# 134   Visited Ad Hoc for NYE with my husband and was...            435
# 147   Agree with all previous negative reviews.Arriv...             64
# 514   Agree with all previous negative reviews.Arriv...             64
# 521   We didn't like the food that much.\n\nThe star...             61
# 526   Visited Ad Hoc for NYE with my husband and was...            435
# 539   Agree with all previous negative reviews.Arriv...             64
# 544   We didn't like the food that much.\n\nThe star...             61
# 549   Visited Ad Hoc for NYE with my husband and was...            435
# 831   The food was very tasteless. The meet was dry ...             45
# 839   Clearly we don't speak or read polish and they...             63
# 841   Nothing to complain about the food, but I feel...            138
# 1053  Service is awful and slow. If you order lunch,...            320
#
#                                           clean_reviews  \
# 2     attractive venue welcoming albeit somewhat slo...
# 3     sadly used high tripadvisor rating literally f...
# 8     got tasting menu wine pairing frankly food tas...
# 14    ate truffle tasting menu wines appetizer good ...
# 22    write negative reviews rather say nothing ever...
# 46    ca understand number two pricey restaurants tr...
# 51    ad hoc restaurant top 60 rating rome family ex...
# 55    reason giving poor terrible staff wonderful at...
# 59    saw amazing reviews ta decided book first nigh...
# 60    bad service literally flag waiter multiple tim...
# 61    ristorante adhoc rome brings best kitchen 2 se...
# 81    sure restaurant well reviewed service friendly...
# 86    excited visiting second best restaurant rome m...
# 90    service staff could even bothered tell us welc...
# 95    go ad hoc mind articifical service tourist sty...
# 98    give food 3 stars average service 1 star terri...
# 104   arrived 10 min earlier wait street offer place...
# 109   visited ad hoc nye husband disappointed evenin...
# 122   agree previous negative reservation told walk ...
# 129   like food much starters tasteless hard digest ...
# 134   visited ad hoc nye husband disappointed evenin...
# 147   agree previous negative reservation told walk ...
# 514   agree previous negative reservation told walk ...
# 521   like food much starters tasteless hard digest ...
# 526   visited ad hoc nye husband disappointed evenin...
# 539   agree previous negative reservation told walk ...
# 544   like food much starters tasteless hard digest ...
# 549   visited ad hoc nye husband disappointed evenin...
# 831   food tasteless meet dry felt like heated micro...
# 839   clearly speak read polish added extra course q...
# 841   nothing complain food feel fairly treated book...
# 1053  service awful slow order lunch might well prep...
#
#                                             title_words
# 2                    {food, bland, pretty, place, with}
# 3      {and, great, inedible, food, but, wine, service}
# 8             {and, food, mediocre, expensive, service}
# 14                   {great, food, average, but, wines}
# 22    {in, food, rome, carbonara, regrettable, pasta...
# 46         {great, food, poor, service, ok, atmosphere}
# 51           {great, food, the, but, ambience, quality}
# 55                       {staff, great, food, terrible}
# 59                      {overpriced, for, subpar, food}
# 60                  {and, food, mediocre, service, bad}
# 61       {in, food, perfection, of, but, service, lack}
# 81                           {people, nice, okay, food}
# 86         {food, average, overated, service, terrible}
# 90          {let, food, a, average, down, service, was}
# 95            {to, a, food, disappointment, lover, big}
# 98    {major, food, average, disappointment, service...
# 104   {and, food, worthy, money, not, spent, the, se...
# 109   {slow, food, of, average, totally, wine, very,...
# 122   {and, of, their, food, no, about, talk, fancy,...
# 129         {to, food, difficult, tasting, digest, bad}
# 134   {slow, food, of, average, totally, wine, very,...
# 147   {and, of, their, food, no, about, talk, fancy,...
# 514   {and, of, their, food, no, about, talk, fancy,...
# 521         {to, food, difficult, tasting, digest, bad}
# 526   {slow, food, of, average, totally, wine, very,...
# 539   {and, of, their, food, no, about, talk, fancy,...
# 544         {to, food, difficult, tasting, digest, bad}
# 549   {slow, food, of, average, totally, wine, very,...
# 831                        {unbelievable, food, boring}
# 839                      {ripped, food, but, good, off}
# 841                      {management, good, poor, food}
# 1053                      {cheap, taste, food, cheaper}

# %%
restaurant_reviews.loc[positive_common_words.index]
# Out:
#       country            restaurant_name sentiment  \
# 156    France  The Frog at Bercy Village  Positive
# 170    France  The Frog at Bercy Village  Positive
# 173    France  The Frog at Bercy Village  Positive
# 178    France  The Frog at Bercy Village  Positive
# 179    France  The Frog at Bercy Village  Positive
# ...       ...                        ...       ...
# 1346  Morroco                   The LOFT  Positive
# 1350  Morroco                   The LOFT  Positive
# 1351  Morroco                   The LOFT  Positive
# 1354  Morroco                   The LOFT  Positive
# 1355  Morroco                   The LOFT  Positive
#
#                                            review_title review_date  \
# 156               Great fast Service and Delicious food  2024-05-01
# 170                           Service and food amazing!  2024-03-01
# 173                     Amazing food and great service.  2024-02-01
# 178   Excellent pub with great vibe offers a range o...  2023-12-01
# 179                                  drinks and food <3  2023-12-01
# ...                                                 ...         ...
# 1346                   Great food, fascinating setting.  2018-09-01
# 1350                                      Stunning Food  2018-08-01
# 1351          Very cool decor and music, excellent food  2018-08-01
# 1354                                       Amazing food  2018-07-01
# 1355                                     Wonderful Food  2018-07-01
#
#                                                  review  review_length  \
# 156   I tried Frog for the first time since my hotel...             78
# 170   Ellen made our group feel comfortable and welc...             27
# 173   Had a very good service by Ellen who served me...             86
# 178   Stopped in for coffee and dessert, wish we had...             66
# 179   The service was really good. preeyansh was my ...             21
# ...                                                 ...            ...
# 1346  I had walked past it and was interested and sa...             76
# 1350  Absolutely delicious! A nice change from tradi...             35
# 1351  Sometimes when a restaurant decor and music ar...            115
# 1354  We went to this place as a treat night as its ...             86
# 1355  Lovely small restaurant serving very tasty foo...             28
#
#                                           clean_reviews  \
# 156   tried frog first time since hotel near must sa...
# 170   ellen made group feel comfortable welcome rest...
# 173   good service ellen served wonderful energy rec...
# 178   stopped coffee dessert wish come lunch instead...
# 179   service really good preeyansh server made sure...
# ...                                                 ...
# 1346  walked past interested saw reviews tempted vis...
# 1350  absolutely delicious nice change traditional m...
# 1351  sometimes restaurant decor music consciously c...
# 1354  went place treat night little expensive restau...
# 1355  lovely small restaurant serving tasty food chi...
#
#                                             title_words
# 156        {delicious, and, great, food, fast, service}
# 170                       {and, amazing, service, food}
# 173                {amazing, and, great, food, service}
# 178   {beers, and, great, of, food, pub, offers, exc...
# 179                              {3, drinks, food, and}
# ...                                                 ...
# 1346                {setting, fascinating, great, food}
# 1350                                   {stunning, food}
# 1351   {and, food, cool, music, very, decor, excellent}
# 1354                                    {amazing, food}
# 1355                                  {food, wonderful}
#
# [178 rows x 9 columns]

# %% [markdown]
# It looks like most titles that contain at least one word from the top 10 list use words like 'food', 'service' and 'wine'. I would say that most of these titles are descriptive about the review.

# %% [markdown]
# ### Problem 5. Bag of words (1 point)
# Based on your findings so far, come up with a good set of settings (hyperparameters) for a bag-of-words model for review titles and contents. It's easiest to treat them separately (so, create two models); but you may also think about a unified representation. I find the simplest way of concatenating the title and content too simplistic to be useful, as it doesn't allow you to treat the title differently (e.g., by giving it more weight).
#
# The documentation for `CountVectorizer` is [here](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html). Familiarize yourself with all settings; try out different combinations and come up with a final model; or rather - two models :).

# %% [markdown]
# I will use bags of one to three words for the reviews and exclude words that are met in less than 5 reviews and ones that appear in more than 90% of reviews.

# %%
review_vectorizer = CountVectorizer(ngram_range=(1,3), max_df=0.90, min_df=5)
review_vectorizer.fit(restaurant_reviews.review)
# Out:
# CountVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 3))

# %%
review_vectors = review_vectorizer.transform(restaurant_reviews.review)
review_vectors
# Out:
# <1502x5886 sparse matrix of type '<class 'numpy.int64'>'
# 	with 111047 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Lets do the same for the titles.

# %%
title_vectorizer = CountVectorizer(ngram_range=(1,3), max_df = 0.90, min_df = 5)
title_vectorizer.fit(restaurant_reviews.review)
# Out:
# CountVectorizer(max_df=0.9, min_df=5, ngram_range=(1, 3))

# %%
title_vectors = title_vectorizer.transform(restaurant_reviews.review_title)
title_vectors
# Out:
# <1502x5886 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7219 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Problem 6. Deep sentiment analysis models (1 point)
# Find a suitable model for sentiment analysis in English. Without modifying, training, or fine-tuning the model, make it predict all contents (or better, combinations of titles and contents, if you can). Meaure the accuracy of the model compared to the `sentiment` column in the dataset.

# %% [markdown]
# I will use the **SentimentIntensityAnalyzer** model from the **NLTK** library and create a function that calculates the sentiment using this model, then apply it to the **reviews** column.

# %%
analyzer = SentimentIntensityAnalyzer()
def analyze_sentiment(text):
    sentiment = analyzer.polarity_scores(text)
    return sentiment['compound']

# %%
restaurant_reviews["predicted_sentiment"] = restaurant_reviews.review.apply(analyze_sentiment)

# %%
restaurant_reviews[["sentiment", "predicted_sentiment"]].sample(30)
# Out:
#      sentiment  predicted_sentiment
# 43    Negative              -0.9162
# 986   Positive               0.8908
# 617   Positive               0.9644
# 1481  Negative               0.8126
# 557   Negative               0.5538
# 1190  Positive               0.9657
# 959   Positive               0.9017
# 1298  Positive               0.8356
# 180   Positive               0.9429
# 1262  Positive               0.9731
# 571   Positive               0.9285
# 100   Negative               0.8761
# 1234  Positive               0.8977
# 336   Positive               0.6588
# 740   Positive               0.9722
# 1198  Positive               0.9690
# 1457  Positive               0.7901
# 1408  Positive               0.9721
# 819   Positive               0.8516
# 1044  Positive               0.8115
# 1323  Positive               0.8442
# 36    Negative               0.4207
# 872   Positive               0.9274
# 551   Negative               0.7150
# 1448  Positive               0.7717
# 826   Positive               0.9580
# 1395  Positive               0.2263
# 307   Positive               0.9778
# 752   Positive               0.9854
# 1377  Positive               0.9413

# %% [markdown]
# The model guesses all the positive reviews correctly, but does mistake some negative reviews as positive.

# %% [markdown]
# ### Problem 7. Deep features (embeddings) (1 point)
# Use the same model to perform feature extraction on the review contents (or contents + titles) instead of direct predictions. You should already be familiar how to do that from your work on images.
#
# Use the cosine similarity between texts to try to cluster them. Are there "similar" reviews (you'll need to find a way to measure similarity) across different restaurants? Are customers generally in agreement for the same restaurant?

# %%
def extract_features(text):
    sentiment = analyzer.polarity_scores(text)
    length = len(text)
    word_count = len(text.split())
    pos_count = sum(1 for word in text.split() if analyzer.polarity_scores(word)['compound'] > 0)
    neg_count = sum(1 for word in text.split() if analyzer.polarity_scores(word)['compound'] < 0)
    
    features = {
        'length': length,
        'word_count': word_count,
        'pos_count': pos_count,
        'neg_count': neg_count,
        'neg': sentiment['neg'],
        'neu': sentiment['neu'],
        'pos': sentiment['pos'],
        'compound': sentiment['compound']
    }
    return features

features_df = restaurant_reviews['review'].apply(lambda x: pd.Series(extract_features(x)))
restaurant_reviews = pd.concat([restaurant_reviews, features_df], axis=1)

# %%
features_df
# Out:
#       length  word_count  pos_count  neg_count    neg    neu    pos  compound
# 0      146.0        28.0        1.0        3.0  0.377  0.623  0.000   -0.9231
# 1      281.0        58.0        1.0        2.0  0.107  0.866  0.027   -0.6705
# 2      260.0        40.0        3.0        1.0  0.158  0.758  0.084   -0.6601
# 3     1513.0       279.0       25.0        8.0  0.091  0.677  0.232    0.9930
# 4     1351.0       243.0        7.0        8.0  0.079  0.845  0.076    0.0224
# ...      ...         ...        ...        ...    ...    ...    ...       ...
# 1497   776.0       147.0        6.0        1.0  0.035  0.844  0.121    0.9345
# 1498   169.0        30.0        1.0        0.0  0.000  0.909  0.091    0.4404
# 1499   150.0        28.0        2.0        2.0  0.180  0.654  0.166   -0.1189
# 1500   356.0        70.0        3.0        0.0  0.036  0.879  0.085    0.5493
# 1501    76.0        14.0        2.0        3.0  0.364  0.365  0.270   -0.3230
#
# [1502 rows x 8 columns]

# %%
similarity_matrix = cosine_similarity(features_df)
similarity_matrix
# Out:
# array([[1.        , 0.99979811, 0.99916742, ..., 0.99992622, 0.99974999,
#         0.99960636],
#        [0.99979811, 1.        , 0.99866869, ..., 0.99975153, 0.9999125 ,
#         0.99899692],
#        [0.99916742, 0.99866869, 1.        , ..., 0.99944391, 0.99911851,
#         0.99883178],
#        ...,
#        [0.99992622, 0.99975153, 0.99944391, ..., 1.        , 0.99985096,
#         0.99957101],
#        [0.99974999, 0.9999125 , 0.99911851, ..., 0.99985096, 1.        ,
#         0.99898656],
#        [0.99960636, 0.99899692, 0.99883178, ..., 0.99957101, 0.99898656,
#         1.        ]])

# %% [markdown]
# ### \* Problem 8. Explore and model at will
# In this lab, we focused on preprocessing and feature extraction and we didn't really have a chance to train (or compare) models. The dataset is maybe too small to be conclusive, but feel free to play around with ready-made models, and train your own.
