# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import json

# Load the JSON file
with open('all.json', 'r') as file:
    json_data = json.load(file)

# Normalize the nested 'data' field
df = pd.json_normalize(
    json_data, 
    record_path='data', 
    meta=['date'], 
    errors='ignore'
)

# %%
df.date = pd.to_datetime(df.date)

# %%
sorted_df = df.sort_values(by = ['date','weeks_on_chart', 'this_week'], ascending = [False, False, True])

# %%
sorted_df[sorted_df.artist.str.contains("Gracie Abrams")]
# Out:
#                           song                                artist  \
# 344569   I Love You, I'm Sorry                         Gracie Abrams
# 344065            Close To You                         Gracie Abrams
# 344060                     Us.  Gracie Abrams Featuring Taylor Swift
# 343946            Close To You                         Gracie Abrams
# 343922                     Us.  Gracie Abrams Featuring Taylor Swift
# 343980                    Risk                         Gracie Abrams
# 343855            Close To You                         Gracie Abrams
# 343735            Close To You                         Gracie Abrams
# 341065  Everywhere, Everything         Noah Kahan With Gracie Abrams
#
#         this_week  last_week  peak_position  weeks_on_chart       date
# 344569         83        NaN             83               1 2024-08-17
# 344065         79       60.0             49               4 2024-07-13
# 344060         74       36.0             36               2 2024-07-13
# 343946         60       69.0             49               3 2024-07-06
# 343922         36        NaN             36               1 2024-07-06
# 343980         94        NaN             94               1 2024-07-06
# 343855         69       49.0             49               2 2024-06-29
# 343735         49        NaN             49               1 2024-06-22
# 341065         79        NaN             79               1 2023-12-16

# %%
no_dupes = sorted_df.drop_duplicates(subset = ["song", "artist"], keep = 'first')

# %%
sorted_df
# Out:
#                                        song  \
# 344495                         Lose Control
# 344507                I Remember Everything
# 344519                         Stick Season
# 344529                              Feather
# 344499                             Cowgirls
# ...                                     ...
# 95                            Over And Over
# 96                         I Believe In You
# 97                          Little Serenade
# 98      I'll Get By (As Long As I Have You)
# 99                                     Judy
#
#                                       artist  this_week  last_week  \
# 344495                           Teddy Swims          9        6.0
# 344507  Zach Bryan Featuring Kacey Musgraves         21       24.0
# 344519                            Noah Kahan         33       30.0
# 344529                     Sabrina Carpenter         43       38.0
# 344499        Morgan Wallen Featuring ERNEST         13       15.0
# ...                                      ...        ...        ...
# 95                           Thurston Harris         96        NaN
# 96                           Robert & Johnny         97        NaN
# 97                         The Ames Brothers         98        NaN
# 98                            Billy Williams         99        NaN
# 99                           Frankie Vaughan        100        NaN
#
#         peak_position  weeks_on_chart       date
# 344495              1              52 2024-08-17
# 344507              1              50 2024-08-17
# 344519              9              45 2024-08-17
# 344529             21              36 2024-08-17
# 344499             12              34 2024-08-17
# ...               ...             ...        ...
# 95                 96               1 1958-08-04
# 96                 97               1 1958-08-04
# 97                 98               1 1958-08-04
# 98                 99               1 1958-08-04
# 99                100               1 1958-08-04
#
# [344587 rows x 7 columns]

# %%
df = df.drop_duplicates(subset = ["song", "artist"])

# %%
dataset_with_lyrics = pd.read_excel("Final processed dataset.xlsx")

# %%
no_dupes
# Out:
#                                        song  \
# 344495                         Lose Control
# 344507                I Remember Everything
# 344519                         Stick Season
# 344529                              Feather
# 344499                             Cowgirls
# ...                                     ...
# 89                                     Stay
# 95                            Over And Over
# 97                          Little Serenade
# 98      I'll Get By (As Long As I Have You)
# 99                                     Judy
#
#                                       artist  this_week  last_week  \
# 344495                           Teddy Swims          9        6.0
# 344507  Zach Bryan Featuring Kacey Musgraves         21       24.0
# 344519                            Noah Kahan         33       30.0
# 344529                     Sabrina Carpenter         43       38.0
# 344499        Morgan Wallen Featuring ERNEST         13       15.0
# ...                                      ...        ...        ...
# 89                         The Ames Brothers         90        NaN
# 95                           Thurston Harris         96        NaN
# 97                         The Ames Brothers         98        NaN
# 98                            Billy Williams         99        NaN
# 99                           Frankie Vaughan        100        NaN
#
#         peak_position  weeks_on_chart       date
# 344495              1              52 2024-08-17
# 344507              1              50 2024-08-17
# 344519              9              45 2024-08-17
# 344529             21              36 2024-08-17
# 344499             12              34 2024-08-17
# ...               ...             ...        ...
# 89                 90               1 1958-08-04
# 95                 96               1 1958-08-04
# 97                 98               1 1958-08-04
# 98                 99               1 1958-08-04
# 99                100               1 1958-08-04
#
# [31447 rows x 7 columns]

# %%
dataset_with_lyrics[dataset_with_lyrics.Performer.str.contains("taylor swift ")]
# Out:
#        Unnamed: 0                                                url  \
# 1724         2487  http://www.billboard.com/charts/hot-100/2012-0...
# 4304         6248  http://www.billboard.com/charts/hot-100/2012-1...
# 11234       16800  https://www.billboard.com/charts/hot-100/2019-...
# 21685      309378  https://www.billboard.com/charts/hot-100/2020-...
#
#            WeekID  Week Position                    Song  \
# 1724     1/7/2012             30            Safe & Sound
# 4304   11/10/2012             67  Everything Has Changed
# 11234    9/7/2019             63  Soon You'll Get Better
# 21685  12/26/2020             34       No Body, No Crime
#
#                                    Performer  \
# 1724   taylor swift featuring the civil wars
# 4304       taylor swift featuring ed sheeran
# 11234    taylor swift featuring dixie chicks
# 21685            taylor swift featuring haim
#
#                                                   SongID  Instance  \
# 1724   Safe & SoundTaylor Swift Featuring The Civil Wars       1.0
# 4304   Everything Has ChangedTaylor Swift Featuring E...       1.0
# 11234  Soon You'll Get BetterTaylor Swift Featuring D...       1.0
# 21685       No Body, No CrimeTaylor Swift Featuring HAIM       NaN
#
#        Previous Week Position  Peak Position  ...  anticipation_normalized  \
# 1724                      NaN           30.0  ...                 0.009947
# 4304                      NaN           67.0  ...                 0.008448
# 11234                     NaN           63.0  ...                 0.020289
# 21685                     NaN            NaN  ...                 0.006566
#
#         fear fear_normalized surprise  surprise_normalized emo_score   happy  \
# 1724   8.792        0.077805    0.344             0.003044    29.057  11.184
# 4304   5.080        0.019614    1.086             0.004193    31.366  14.362
# 11234  2.741        0.020304    1.025             0.007593    21.884   9.199
# 21685  2.767        0.015811    0.977             0.005583    20.691  10.505
#
#        happy_normalized  sorrow sorrow_normalized
# 1724           0.098973  17.873          0.158168
# 4304           0.055452  17.004          0.065653
# 11234          0.068141  12.685          0.093963
# 21685          0.060029  10.186          0.058206
#
# [4 rows x 49 columns]

# %%
dataset_with_lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22600 entries, 0 to 22599
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               22600 non-null  int64
#  1   url                      22600 non-null  object
#  2   WeekID                   22600 non-null  object
#  3   Week Position            22600 non-null  int64
#  4   Song                     22600 non-null  object
#  5   Performer                22600 non-null  object
#  6   SongID                   22600 non-null  object
#  7   Instance                 22046 non-null  float64
#  8   Previous Week Position   5058 non-null   float64
#  9   Peak Position            22046 non-null  float64
#  10  Weeks on Chart           22046 non-null  float64
#  11  Lyrics                   22600 non-null  object
#  12  Artist                   22600 non-null  object
#  13  words                    22600 non-null  object
#  14  wordCount                22600 non-null  int64
#  15  languages                22600 non-null  object
#  16  all_words                22600 non-null  object
#  17  allWordCount             22600 non-null  int64
#  18  year                     22600 non-null  int64
#  19  decade                   22600 non-null  object
#  20  MTLD                     22600 non-null  float64
#  21  TTR                      22600 non-null  float64
#  22  CTTR                     22600 non-null  float64
#  23  sentimentScore           22600 non-null  float64
#  24  sentimentScore_pos       22600 non-null  float64
#  25  sentimentScore_neg       22600 non-null  float64
#  26  emo_words                22600 non-null  object
#  27  emoWordCount             22600 non-null  int64
#  28  joy                      22600 non-null  float64
#  29  joy_normalized           22600 non-null  float64
#  30  sadness                  22600 non-null  float64
#  31  sadness_normalized       22600 non-null  float64
#  32  anger                    22600 non-null  float64
#  33  anger_normalized         22600 non-null  float64
#  34  disgust                  22600 non-null  float64
#  35  disgust_normalized       22600 non-null  float64
#  36  trust                    22600 non-null  float64
#  37  trust_normalized         22600 non-null  float64
#  38  anticipation             22600 non-null  float64
#  39  anticipation_normalized  22600 non-null  float64
#  40  fear                     22600 non-null  float64
#  41  fear_normalized          22600 non-null  float64
#  42  surprise                 22600 non-null  float64
#  43  surprise_normalized      22600 non-null  float64
#  44  emo_score                22600 non-null  float64
#  45  happy                    22600 non-null  float64
#  46  happy_normalized         22600 non-null  float64
#  47  sorrow                   22600 non-null  float64
#  48  sorrow_normalized        22600 non-null  float64
# dtypes: float64(31), int64(6), object(12)
# memory usage: 8.4+ MB

# %%
no_dupes
# Out:
#                                        song  \
# 344495                         Lose Control
# 344507                I Remember Everything
# 344519                         Stick Season
# 344529                              Feather
# 344499                             Cowgirls
# ...                                     ...
# 89                                     Stay
# 95                            Over And Over
# 97                          Little Serenade
# 98      I'll Get By (As Long As I Have You)
# 99                                     Judy
#
#                                       artist  this_week  last_week  \
# 344495                           Teddy Swims          9        6.0
# 344507  Zach Bryan Featuring Kacey Musgraves         21       24.0
# 344519                            Noah Kahan         33       30.0
# 344529                     Sabrina Carpenter         43       38.0
# 344499        Morgan Wallen Featuring ERNEST         13       15.0
# ...                                      ...        ...        ...
# 89                         The Ames Brothers         90        NaN
# 95                           Thurston Harris         96        NaN
# 97                         The Ames Brothers         98        NaN
# 98                            Billy Williams         99        NaN
# 99                           Frankie Vaughan        100        NaN
#
#         peak_position  weeks_on_chart       date
# 344495              1              52 2024-08-17
# 344507              1              50 2024-08-17
# 344519              9              45 2024-08-17
# 344529             21              36 2024-08-17
# 344499             12              34 2024-08-17
# ...               ...             ...        ...
# 89                 90               1 1958-08-04
# 95                 96               1 1958-08-04
# 97                 98               1 1958-08-04
# 98                 99               1 1958-08-04
# 99                100               1 1958-08-04
#
# [31447 rows x 7 columns]

# %%
no_dupes.artist = no_dupes.artist.str.lower()
# Out:
# C:\Users\ferad\AppData\Local\Temp\ipykernel_1904\3084224278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_dupes.artist = no_dupes.artist.str.lower()

# %%
merged_df = pd.merge(left = no_dupes, right = dataset_with_lyrics, left_on = ["song", "artist"], right_on = ["Song", "Performer"])

# %%
merged_df
# Out:
#                                     song             artist  this_week  \
# 0                           Cruel Summer       taylor swift         20
# 1                               Fast Car      tracy chapman         42
# 2        All I Want For Christmas Is You       mariah carey          2
# 3      Rockin' Around The Christmas Tree         brenda lee          1
# 4                A Holly Jolly Christmas          burl ives          5
# ...                                  ...                ...        ...
# 19501                  Beautiful Delilah        chuck berry         81
# 19502                        To Be Loved      jackie wilson         86
# 19503                      Over And Over    thurston harris         96
# 19504                    Little Serenade  the ames brothers         98
# 19505                               Judy    frankie vaughan        100
#
#        last_week  peak_position  weeks_on_chart       date  Unnamed: 0  \
# 0           24.0              1              54 2024-05-25        2470
# 1            NaN              6              22 2024-02-17       19322
# 2            1.0              1              65 2024-01-06       32443
# 3            2.0              1              58 2024-01-06       16807
# 4            5.0              4              39 2024-01-06       14676
# ...          ...            ...             ...        ...         ...
# 19501        NaN             81               1 1958-08-04       31634
# 19502        NaN             86               1 1958-08-04      286783
# 19503        NaN             96               1 1958-08-04       47343
# 19504        NaN             98               1 1958-08-04       25505
# 19505        NaN            100               1 1958-08-04       13286
#
#                                                      url      WeekID  ...  \
# 0      https://www.billboard.com/charts/hot-100/2019-...    9/7/2019  ...
# 1      http://www.billboard.com/charts/hot-100/1988-0...    6/4/1988  ...
# 2      http://www.billboard.com/charts/hot-100/2000-0...    1/8/2000  ...
# 3      http://www.billboard.com/charts/hot-100/1960-1...  12/10/1960  ...
# 4      http://www.billboard.com/charts/hot-100/2017-0...    1/7/2017  ...
# ...                                                  ...         ...  ...
# 19501  http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958  ...
# 19502  http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958  ...
# 19503  http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958  ...
# 19504  http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958  ...
# 19505  http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958  ...
#
#        anticipation_normalized    fear fear_normalized surprise  \
# 0                     0.025705  10.039        0.041656    2.414
# 1                     0.018261   2.622        0.009784    1.703
# 2                     0.020958   0.000        0.000000    0.913
# 3                     0.051654   0.000        0.000000    0.773
# 4                     0.045292   0.188        0.002112    1.163
# ...                        ...     ...             ...      ...
# 19501                 0.044403   0.547        0.007104    1.078
# 19502                 0.046722   0.824        0.015259    1.101
# 19503                 0.060645   1.773        0.014653    0.282
# 19504                 0.056108   2.118        0.019081    1.094
# 19505                 0.026677   1.959        0.030138    2.351
#
#        surprise_normalized  emo_score   happy  happy_normalized  sorrow  \
# 0                 0.010017     71.534  28.071          0.116477  43.463
# 1                 0.006354     30.429  17.813          0.066466  12.616
# 2                 0.004805     34.301  25.618          0.134832   8.683
# 3                 0.009543     24.074  19.700          0.243210   4.374
# 4                 0.013067     24.038  19.363          0.217562   4.675
# ...                    ...        ...     ...               ...     ...
# 19501             0.014000     15.937  10.065          0.130714   5.872
# 19502             0.020389     33.329  26.523          0.491167   6.806
# 19503             0.002331     19.844   6.817          0.056339  13.027
# 19504             0.009856     36.331  24.825          0.223649  11.506
# 19505             0.036169     15.911   7.303          0.112354   8.608
#
#       sorrow_normalized
# 0              0.180344
# 1              0.047075
# 2              0.045700
# 3              0.054000
# 4              0.052528
# ...                 ...
# 19501          0.076260
# 19502          0.126037
# 19503          0.107661
# 19504          0.103658
# 19505          0.132431
#
# [19506 rows x 56 columns]

# %%
merged_df.year.value_counts()
# Out:
# year
# 2020    443
# 1966    440
# 1967    434
# 1965    430
# 1969    418
#        ...
# 2001    218
# 1995    218
# 1997    214
# 1958    180
# 1996    178
# Name: count, Length: 63, dtype: int64
