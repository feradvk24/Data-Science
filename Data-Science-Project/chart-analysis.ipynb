# %%
import pandas as pd
import json
import requests
import concurrent.futures
import numpy as np
import time

# %%
# Load the JSON file
with open('all.json', 'r') as file:
    json_data = json.load(file)

# Normalize the nested 'data' field
df = pd.json_normalize(
    json_data, 
    record_path='data', 
    meta=['date'], 
    errors='ignore'
)

# %%
df.date = pd.to_datetime(df.date)

# %%
sorted_df = df.sort_values(by = ['date','weeks_on_chart', 'this_week'], ascending = [False, False, True])

# %%
sorted_df[sorted_df.artist.str.contains("Gracie Abrams")]
# Out:
#                           song                                artist  \
# 344569   I Love You, I'm Sorry                         Gracie Abrams
# 344065            Close To You                         Gracie Abrams
# 344060                     Us.  Gracie Abrams Featuring Taylor Swift
# 343946            Close To You                         Gracie Abrams
# 343922                     Us.  Gracie Abrams Featuring Taylor Swift
# 343980                    Risk                         Gracie Abrams
# 343855            Close To You                         Gracie Abrams
# 343735            Close To You                         Gracie Abrams
# 341065  Everywhere, Everything         Noah Kahan With Gracie Abrams
#
#         this_week  last_week  peak_position  weeks_on_chart       date
# 344569         83        NaN             83               1 2024-08-17
# 344065         79       60.0             49               4 2024-07-13
# 344060         74       36.0             36               2 2024-07-13
# 343946         60       69.0             49               3 2024-07-06
# 343922         36        NaN             36               1 2024-07-06
# 343980         94        NaN             94               1 2024-07-06
# 343855         69       49.0             49               2 2024-06-29
# 343735         49        NaN             49               1 2024-06-22
# 341065         79        NaN             79               1 2023-12-16

# %%
no_dupes = sorted_df.drop_duplicates(subset = ["song", "artist"], keep = 'first')

# %%
sorted_df
# Out:
#                                        song  \
# 344495                         Lose Control
# 344507                I Remember Everything
# 344519                         Stick Season
# 344529                              Feather
# 344499                             Cowgirls
# ...                                     ...
# 95                            Over And Over
# 96                         I Believe In You
# 97                          Little Serenade
# 98      I'll Get By (As Long As I Have You)
# 99                                     Judy
#
#                                       artist  this_week  last_week  \
# 344495                           Teddy Swims          9        6.0
# 344507  Zach Bryan Featuring Kacey Musgraves         21       24.0
# 344519                            Noah Kahan         33       30.0
# 344529                     Sabrina Carpenter         43       38.0
# 344499        Morgan Wallen Featuring ERNEST         13       15.0
# ...                                      ...        ...        ...
# 95                           Thurston Harris         96        NaN
# 96                           Robert & Johnny         97        NaN
# 97                         The Ames Brothers         98        NaN
# 98                            Billy Williams         99        NaN
# 99                           Frankie Vaughan        100        NaN
#
#         peak_position  weeks_on_chart       date
# 344495              1              52 2024-08-17
# 344507              1              50 2024-08-17
# 344519              9              45 2024-08-17
# 344529             21              36 2024-08-17
# 344499             12              34 2024-08-17
# ...               ...             ...        ...
# 95                 96               1 1958-08-04
# 96                 97               1 1958-08-04
# 97                 98               1 1958-08-04
# 98                 99               1 1958-08-04
# 99                100               1 1958-08-04
#
# [344587 rows x 7 columns]

# %%
dataset_with_lyrics = pd.read_excel("Final processed dataset.xlsx")

# %%
no_dupes
# Out:
#                                        song  \
# 344495                         Lose Control
# 344507                I Remember Everything
# 344519                         Stick Season
# 344529                              Feather
# 344499                             Cowgirls
# ...                                     ...
# 89                                     Stay
# 95                            Over And Over
# 97                          Little Serenade
# 98      I'll Get By (As Long As I Have You)
# 99                                     Judy
#
#                                       artist  this_week  last_week  \
# 344495                           Teddy Swims          9        6.0
# 344507  Zach Bryan Featuring Kacey Musgraves         21       24.0
# 344519                            Noah Kahan         33       30.0
# 344529                     Sabrina Carpenter         43       38.0
# 344499        Morgan Wallen Featuring ERNEST         13       15.0
# ...                                      ...        ...        ...
# 89                         The Ames Brothers         90        NaN
# 95                           Thurston Harris         96        NaN
# 97                         The Ames Brothers         98        NaN
# 98                            Billy Williams         99        NaN
# 99                           Frankie Vaughan        100        NaN
#
#         peak_position  weeks_on_chart       date
# 344495              1              52 2024-08-17
# 344507              1              50 2024-08-17
# 344519              9              45 2024-08-17
# 344529             21              36 2024-08-17
# 344499             12              34 2024-08-17
# ...               ...             ...        ...
# 89                 90               1 1958-08-04
# 95                 96               1 1958-08-04
# 97                 98               1 1958-08-04
# 98                 99               1 1958-08-04
# 99                100               1 1958-08-04
#
# [31447 rows x 7 columns]

# %%
dataset_with_lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22600 entries, 0 to 22599
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               22600 non-null  int64
#  1   url                      22600 non-null  object
#  2   WeekID                   22600 non-null  object
#  3   Week Position            22600 non-null  int64
#  4   Song                     22600 non-null  object
#  5   Performer                22600 non-null  object
#  6   SongID                   22600 non-null  object
#  7   Instance                 22046 non-null  float64
#  8   Previous Week Position   5058 non-null   float64
#  9   Peak Position            22046 non-null  float64
#  10  Weeks on Chart           22046 non-null  float64
#  11  Lyrics                   22600 non-null  object
#  12  Artist                   22600 non-null  object
#  13  words                    22600 non-null  object
#  14  wordCount                22600 non-null  int64
#  15  languages                22600 non-null  object
#  16  all_words                22600 non-null  object
#  17  allWordCount             22600 non-null  int64
#  18  year                     22600 non-null  int64
#  19  decade                   22600 non-null  object
#  20  MTLD                     22600 non-null  float64
#  21  TTR                      22600 non-null  float64
#  22  CTTR                     22600 non-null  float64
#  23  sentimentScore           22600 non-null  float64
#  24  sentimentScore_pos       22600 non-null  float64
#  25  sentimentScore_neg       22600 non-null  float64
#  26  emo_words                22600 non-null  object
#  27  emoWordCount             22600 non-null  int64
#  28  joy                      22600 non-null  float64
#  29  joy_normalized           22600 non-null  float64
#  30  sadness                  22600 non-null  float64
#  31  sadness_normalized       22600 non-null  float64
#  32  anger                    22600 non-null  float64
#  33  anger_normalized         22600 non-null  float64
#  34  disgust                  22600 non-null  float64
#  35  disgust_normalized       22600 non-null  float64
#  36  trust                    22600 non-null  float64
#  37  trust_normalized         22600 non-null  float64
#  38  anticipation             22600 non-null  float64
#  39  anticipation_normalized  22600 non-null  float64
#  40  fear                     22600 non-null  float64
#  41  fear_normalized          22600 non-null  float64
#  42  surprise                 22600 non-null  float64
#  43  surprise_normalized      22600 non-null  float64
#  44  emo_score                22600 non-null  float64
#  45  happy                    22600 non-null  float64
#  46  happy_normalized         22600 non-null  float64
#  47  sorrow                   22600 non-null  float64
#  48  sorrow_normalized        22600 non-null  float64
# dtypes: float64(31), int64(6), object(12)
# memory usage: 8.4+ MB

# %%
no_dupes
# Out:
#                                        song  \
# 344495                         Lose Control
# 344507                I Remember Everything
# 344519                         Stick Season
# 344529                              Feather
# 344499                             Cowgirls
# ...                                     ...
# 89                                     Stay
# 95                            Over And Over
# 97                          Little Serenade
# 98      I'll Get By (As Long As I Have You)
# 99                                     Judy
#
#                                       artist  this_week  last_week  \
# 344495                           Teddy Swims          9        6.0
# 344507  Zach Bryan Featuring Kacey Musgraves         21       24.0
# 344519                            Noah Kahan         33       30.0
# 344529                     Sabrina Carpenter         43       38.0
# 344499        Morgan Wallen Featuring ERNEST         13       15.0
# ...                                      ...        ...        ...
# 89                         The Ames Brothers         90        NaN
# 95                           Thurston Harris         96        NaN
# 97                         The Ames Brothers         98        NaN
# 98                            Billy Williams         99        NaN
# 99                           Frankie Vaughan        100        NaN
#
#         peak_position  weeks_on_chart       date
# 344495              1              52 2024-08-17
# 344507              1              50 2024-08-17
# 344519              9              45 2024-08-17
# 344529             21              36 2024-08-17
# 344499             12              34 2024-08-17
# ...               ...             ...        ...
# 89                 90               1 1958-08-04
# 95                 96               1 1958-08-04
# 97                 98               1 1958-08-04
# 98                 99               1 1958-08-04
# 99                100               1 1958-08-04
#
# [31447 rows x 7 columns]

# %%
no_dupes.artist = no_dupes.artist.str.lower()
# Out:
# C:\Users\ferad\AppData\Local\Temp\ipykernel_1068\3084224278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_dupes.artist = no_dupes.artist.str.lower()

# %%
merged_df = pd.merge(left = no_dupes, right = dataset_with_lyrics, left_on = ["song", "artist"], right_on = ["Song", "Performer"], how = "left")

# %%
merged_df
# Out:
#                                       song  \
# 0                             Lose Control
# 1                    I Remember Everything
# 2                             Stick Season
# 3                                  Feather
# 4                                 Cowgirls
# ...                                    ...
# 31445                                 Stay
# 31446                        Over And Over
# 31447                      Little Serenade
# 31448  I'll Get By (As Long As I Have You)
# 31449                                 Judy
#
#                                      artist  this_week  last_week  \
# 0                               teddy swims          9        6.0
# 1      zach bryan featuring kacey musgraves         21       24.0
# 2                                noah kahan         33       30.0
# 3                         sabrina carpenter         43       38.0
# 4            morgan wallen featuring ernest         13       15.0
# ...                                     ...        ...        ...
# 31445                     the ames brothers         90        NaN
# 31446                       thurston harris         96        NaN
# 31447                     the ames brothers         98        NaN
# 31448                        billy williams         99        NaN
# 31449                       frankie vaughan        100        NaN
#
#        peak_position  weeks_on_chart       date  Unnamed: 0  \
# 0                  1              52 2024-08-17         NaN
# 1                  1              50 2024-08-17         NaN
# 2                  9              45 2024-08-17         NaN
# 3                 21              36 2024-08-17         NaN
# 4                 12              34 2024-08-17         NaN
# ...              ...             ...        ...         ...
# 31445             90               1 1958-08-04         NaN
# 31446             96               1 1958-08-04     47343.0
# 31447             98               1 1958-08-04     25505.0
# 31448             99               1 1958-08-04         NaN
# 31449            100               1 1958-08-04     13286.0
#
#                                                      url    WeekID  ...  \
# 0                                                    NaN       NaN  ...
# 1                                                    NaN       NaN  ...
# 2                                                    NaN       NaN  ...
# 3                                                    NaN       NaN  ...
# 4                                                    NaN       NaN  ...
# ...                                                  ...       ...  ...
# 31445                                                NaN       NaN  ...
# 31446  http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958  ...
# 31447  http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958  ...
# 31448                                                NaN       NaN  ...
# 31449  http://www.billboard.com/charts/hot-100/1958-0...  8/2/1958  ...
#
#        anticipation_normalized   fear fear_normalized surprise  \
# 0                          NaN    NaN             NaN      NaN
# 1                          NaN    NaN             NaN      NaN
# 2                          NaN    NaN             NaN      NaN
# 3                          NaN    NaN             NaN      NaN
# 4                          NaN    NaN             NaN      NaN
# ...                        ...    ...             ...      ...
# 31445                      NaN    NaN             NaN      NaN
# 31446                 0.060645  1.773        0.014653    0.282
# 31447                 0.056108  2.118        0.019081    1.094
# 31448                      NaN    NaN             NaN      NaN
# 31449                 0.026677  1.959        0.030138    2.351
#
#        surprise_normalized  emo_score   happy  happy_normalized  sorrow  \
# 0                      NaN        NaN     NaN               NaN     NaN
# 1                      NaN        NaN     NaN               NaN     NaN
# 2                      NaN        NaN     NaN               NaN     NaN
# 3                      NaN        NaN     NaN               NaN     NaN
# 4                      NaN        NaN     NaN               NaN     NaN
# ...                    ...        ...     ...               ...     ...
# 31445                  NaN        NaN     NaN               NaN     NaN
# 31446             0.002331     19.844   6.817          0.056339  13.027
# 31447             0.009856     36.331  24.825          0.223649  11.506
# 31448                  NaN        NaN     NaN               NaN     NaN
# 31449             0.036169     15.911   7.303          0.112354   8.608
#
#       sorrow_normalized
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 31445               NaN
# 31446          0.107661
# 31447          0.103658
# 31448               NaN
# 31449          0.132431
#
# [31450 rows x 56 columns]

# %%
merged_df[['Lyrics']]
# Out:
#                                                   Lyrics
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 31445                                                NaN
# 31446  doo doo doo doo\n\nwell i went to a dance the ...
# 31447  the ames brothers\nmiscellaneous\nmelodie d'am...
# 31448                                                NaN
# 31449  if her voice can bring\nevery hope of spring\n...
#
# [31450 rows x 1 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31450 entries, 0 to 31449
# Data columns (total 56 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   song                     31450 non-null  object
#  1   artist                   31450 non-null  object
#  2   this_week                31450 non-null  int64
#  3   last_week                27502 non-null  float64
#  4   peak_position            31450 non-null  int64
#  5   weeks_on_chart           31450 non-null  int64
#  6   date                     31450 non-null  datetime64[ns]
#  7   Unnamed: 0               19506 non-null  float64
#  8   url                      19506 non-null  object
#  9   WeekID                   19506 non-null  object
#  10  Week Position            19506 non-null  float64
#  11  Song                     19506 non-null  object
#  12  Performer                19506 non-null  object
#  13  SongID                   19506 non-null  object
#  14  Instance                 19063 non-null  float64
#  15  Previous Week Position   4366 non-null   float64
#  16  Peak Position            19063 non-null  float64
#  17  Weeks on Chart           19063 non-null  float64
#  18  Lyrics                   19506 non-null  object
#  19  Artist                   19506 non-null  object
#  20  words                    19506 non-null  object
#  21  wordCount                19506 non-null  float64
#  22  languages                19506 non-null  object
#  23  all_words                19506 non-null  object
#  24  allWordCount             19506 non-null  float64
#  25  year                     19506 non-null  float64
#  26  decade                   19506 non-null  object
#  27  MTLD                     19506 non-null  float64
#  28  TTR                      19506 non-null  float64
#  29  CTTR                     19506 non-null  float64
#  30  sentimentScore           19506 non-null  float64
#  31  sentimentScore_pos       19506 non-null  float64
#  32  sentimentScore_neg       19506 non-null  float64
#  33  emo_words                19506 non-null  object
#  34  emoWordCount             19506 non-null  float64
#  35  joy                      19506 non-null  float64
#  36  joy_normalized           19506 non-null  float64
#  37  sadness                  19506 non-null  float64
#  38  sadness_normalized       19506 non-null  float64
#  39  anger                    19506 non-null  float64
#  40  anger_normalized         19506 non-null  float64
#  41  disgust                  19506 non-null  float64
#  42  disgust_normalized       19506 non-null  float64
#  43  trust                    19506 non-null  float64
#  44  trust_normalized         19506 non-null  float64
#  45  anticipation             19506 non-null  float64
#  46  anticipation_normalized  19506 non-null  float64
#  47  fear                     19506 non-null  float64
#  48  fear_normalized          19506 non-null  float64
#  49  surprise                 19506 non-null  float64
#  50  surprise_normalized      19506 non-null  float64
#  51  emo_score                19506 non-null  float64
#  52  happy                    19506 non-null  float64
#  53  happy_normalized         19506 non-null  float64
#  54  sorrow                   19506 non-null  float64
#  55  sorrow_normalized        19506 non-null  float64
# dtypes: datetime64[ns](1), float64(38), int64(3), object(14)
# memory usage: 13.4+ MB

# %%
missing_lyrics = merged_df[merged_df.Lyrics.isnull()]
